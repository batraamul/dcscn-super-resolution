# %% [markdown]
# <a href="https://colab.research.google.com/github/batraamul/dcscn-super-resolution/blob/master/Copy_of_Test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/batraamul/dcscn-super-resolution
# Out:
# Cloning into 'dcscn-super-resolution'...
# remote: Enumerating objects: 1273, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 1273 (delta 20), reused 14 (delta 5), pack-reused 1227
# Receiving objects: 100% (1273/1273), 388.67 MiB | 33.60 MiB/s, done.
# Resolving deltas: 100% (521/521), done.
# Checking out files: 100% (475/475), done.

# %%
cd dcscn-super-resolution
# Out:
# /content/dcscn-super-resolution

# %%
import sys

# %%
run train.py --dataset=bsd200 --layers=8 --filters=96 --training_images=30000
# Out:
# DCSCN v2-------------------------------------
# 2021/6/24 17:6:3 [dcscn_L8_F96to48_NIN_A64_PS_R1F32]
# Python Interpreter version:3.7
# tensorflow version:2.5.0
# numpy version:1.19.5
# Session and graph initialized.
# I am in Dynamic Load Function
# THIS FUNCTION IS CALLED
# 2
# 1
# bicubic
# 48
# This was the initial declaration
#    I AM IN DYNAMIC DATA SET FUNCTION OF THE LOADER-> DYNAMIC DATASET CLASS
# I am in Set_Data_Dir
# Feature:96 82 75 68 62 57 52 48  Total: (540)64 32 32 384 1  Complexity:687,268 Receptive Fields:21
# ...

# %%
run train.py --as
# Out:
# Python Interpreter version:3.7
# tensorflow version:2.5.0
# numpy version:1.19.5
#  I am in this function for test
# Unknown args:['train.py', '--as']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /content/dcscn-super-resolution/train.py in <module>()
#     124
#     125 if __name__ == '__main__':
# --> 126     tf.app.run()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/platform/app.py in run(main, argv)
#      38   main = main or _sys.modules['__main__'].main
#      39
# ---> 40   _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#
# /usr/local/lib/python3.7/dist-packages/absl/app.py in run(main, argv, flags_parser)
#     301       callback()
#     302     try:
# --> 303       _run_main(main, args)
#     304     except UsageError as error:
#     305       usage(shorthelp=True, detailed_error=error, exitcode=error.exitcode)
#
# ...
